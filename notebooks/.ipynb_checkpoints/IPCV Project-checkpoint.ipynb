# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import math
#warnings.filterwarnings("ignore")

# %%
def int_to_bin(rgb):
        """Convert an integer tuple to a binary (string) tuple.
        :param rgb: An integer tuple (e.g. (220, 110, 96))
        :return: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        """
        r, g, b = rgb
        return ('{0:08b}'.format(r),
                '{0:08b}'.format(g),
                '{0:08b}'.format(b))
    
def merge_rgb(rgb1, rgb2):
        """Merge two RGB tuples.
        :param rgb1: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        :param rgb2: Another string tuple
        (e.g. ("00101010", "11101011", "00010110"))
        :return: An integer tuple with the two RGB values merged.
        """
        r1, g1, b1 = rgb1
        r2, g2, b2 = rgb2
        rgb = (r1[:4] + r2[:4],
               g1[:4] + g2[:4],
               b1[:4] + b2[:4])
        return rgb
    
def bin_to_int(rgb):
        """Convert a binary (string) tuple to an integer tuple.
        :param rgb: A string tuple (e.g. ("00101010", "11101011", "00010110"))
        :return: Return an int tuple (e.g. (220, 110, 96))
        """
        r, g, b = rgb
        return (int(r, 2),
                int(g, 2),
                int(b, 2))
def merge(img1, img2):
        """Merge two images. The second one will be merged into the first one.
        :param img1: First image
        :param img2: Second image
        :return: A new merged image.
        """

        # Check the images dimensions
        if img2.shape[0] > img1.shape[0] or img2.shape[1] > img1.shape[1]:
            raise ValueError('Image 2 should not be larger than Image 1!')

        # Get the pixel map of the two images
       # pixel_map1 = img1.load()
        #pixel_map2 = img2.load()

        # Create a new image that will be outputted
        #new_image = Image.new(img1.mode, img1.size)
        new_image=np.empty(img1.shape)
        
        #pixels_new = new_image.load()

        for i in range(img1.shape[0]): #sending each pixel to convert it into binary
            for j in range(img1.shape[1]):
                rgb1 = int_to_bin(img1[i, j])

                # Use a black pixel as default
                rgb2 =  int_to_bin((0, 0, 0))

                # Check if the pixel map position is valid for the second image
                if i < img2.shape[0] and j < img2.shape[1]:
                    rgb2 = int_to_bin(img2[i, j])

                # Merge the two pixels and convert it to a integer tuple
                rgb = merge_rgb(rgb1, rgb2)

                new_image[i, j] =bin_to_int(rgb)
       # new_image.astype(int)
       # new_image=np.clip(new_image,a_min=0,a_max=255)
       # new_image = (new_image -new_image.min())/( new_image.max() -  new_image.min())
        return new_image
    
def hide(img1, img2, output): #img1 is cover 
    merged_image = merge(plt.imread(img1), plt.imread(img2))
    merged_image1 = (merged_image -merged_image.min())/( merged_image.max() -  merged_image.min())
    plt.imshow(merged_image1)
    return merged_image
   # print(merged_image)
    
def unmerge(img):
        """Unmerge an image.
        :param img: The input image.
        :return: The unmerged/extracted image.
        """

        # Load the pixel map
        #pixel_map = img.load()

        # Create the new image and load the pixel map
        new_image = np.empty(img.shape)
        #pixels_new = new_image.load()

        # Tuple used to store the image original size
        original_size = (img.shape[0],img.shape[1])

        for i in range(img.shape[0]):
            for j in range(img.shape[1]):
                # Get the RGB (as a string tuple) from the current pixel
                r,g,b=int_to_bin((int(img[i, j, 0]),int(img[i, j, 1]),int(img[i, j, 2])))
                
               # r = int_to_bin(int(img[i, j, 0]))
               # g = int_to_bin(int(img[i, j, 1]))
               # b = int_to_bin(int(img[i, j, 2]))
                
                #r, g, b = int_to_bin(img[i, j])

                # Extract the last 4 bits (corresponding to the hidden image)
                # Concatenate 4 zero bits because we are working with 8 bit
                rgb = (r[4:] + '0000',
                       g[4:] + '0000',
                       b[4:] + '0000')

                # Convert it to an integer tuple
                #print(bin_to_int(rgb))
                new_image[i, j] =bin_to_int(rgb)
                

                # If this is a 'valid' position, store it
                # as the last valid position
                #if new_image[i, j] != (0, 0, 0):
                original_size = (i + 1, j + 1)

        # Crop the image based on the 'valid' pixels
        new_image = new_image[0:original_size[0],0:original_size[1]]
        new_image = (new_image -new_image.min())/( new_image.max() -  new_image.min())
        return new_image
    
def unhide(img):
    unmerged_image =unmerge(img)
    plt.imshow(unmerged_image)

# %%
merged_image=hide('../data/img1.jpg','../data/img2.jpg',0)

# %%
unhide(merged_image)

# %%
merged_image = hide('../data/img2.jpg','../data/Rose.jpg',0)

# %%
unhide(merged_image)

# %%
merged_image = hide('data/messi5.jpg','data/bird_small.png',0)
unhide(merged_image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-fd9cfcdc0ffa> in <module>()
# ----> 1 merged_image = hide('data/messi5.jpg','data/bird_small.png',0)
#       2 unhide(merged_image)
#
# <ipython-input-3-d51d6b12636a> in hide(img1, img2, output)
#      74
#      75 def hide(img1, img2, output): #img1 is cover
# ---> 76     merged_image = merge(plt.imread(img1), plt.imread(img2))
#      77     merged_image1 = (merged_image -merged_image.min())/( merged_image.max() -  merged_image.min())
#      78     plt.imshow(merged_image1)
#
# <ipython-input-3-d51d6b12636a> in merge(img1, img2)
#      62                 # Check if the pixel map position is valid for the second image
#      63                 if i < img2.shape[0] and j < img2.shape[1]:
# ---> 64                     rgb2 = int_to_bin(img2[i, j])
#      65
# ...

# %% [markdown]
# ---
# **HSI**
#
# ---

# %%
import cv2
import numpy as np
import math

def RGB_TO_HSI(img):

    with np.errstate(divide='ignore', invalid='ignore'):

        #Load image with 32 bit floats as variable type
        bgr = np.float32(img)/255

        #Separate color channels
        blue = bgr[:,:,0]
        green = bgr[:,:,1]
        red = bgr[:,:,2]

        #Calculate Intensity
        def calc_intensity(red, blue, green):
            return np.divide(blue + green + red, 3)

        #Calculate Saturation
        def calc_saturation(red, blue, green):
            minimum = np.minimum(np.minimum(red, green), blue)
            saturation = 1 - (3* minimum)*100

            return saturation

        #Calculate Hue
        def calc_hue(red, blue, green):
            hue = np.copy(red)

            for i in range(0, blue.shape[0]):
                for j in range(0, blue.shape[1]):
                    hue[i][j] = 0.5 * ((red[i][j] - green[i][j]) + (red[i][j] - blue[i][j])) / \
                                math.sqrt((red[i][j] - green[i][j])**2 +
                                        ((red[i][j] - blue[i][j]) * (green[i][j] - blue[i][j])))
                    hue[i][j] = math.acos(hue[i][j])

                    if blue[i][j] <= green[i][j]:
                        hue[i][j] = hue[i][j]
                    else:
                        hue[i][j] = ((360 * math.pi) / 180.0) - hue[i][j]
            
            #hue = (hue * 180)/np.pi
            return hue

        #Merge channels into picture and return image
        hsi = cv2.merge((calc_hue(red, blue, green), calc_saturation(red, blue, green), calc_intensity(red, blue, green)))
        
        
        #hsi = int((hsi -hsi.min())/( hsi.max() -  hsi.min())*255)
        
        return hsi

# %%
hsi = RGB_TO_HSI(plt.imread("img3.jpg"))
cv2.imshow('HSI Image', hsi)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def HSI_TO_RGB(hsi):
    
    h = (hsi[:, :, 0]*360)
    s = (hsi[:,:, 1])
    i = (hsi[:,:, 2]/255)
    
    #ones = np.ones(hsi.shape[:1,:])
    x = i*(1 - s)
    y = i*(1 + (s * np.cos(h)/np.cos(np.pi/3 - h) ) )
    z = 3*i - x - y
    
    r = np.empty([hsi.shape[0], hsi.shape[1]])
    g = np.empty([hsi.shape[0], hsi.shape[1]])
    b = np.empty([hsi.shape[0], hsi.shape[1]]) 
    
    for i in range((hsi.shape[0])):
        for j in range((hsi.shape[1])):
            if(h[i, j] < (2*np.pi/3)):
                r[i, j], g[i, j], b[i, j] = y[i, j], z[i, j], x[i, j]
                h[i, j] = h[i, j] - (2*np.pi/3)
            else:
                r[i, j], g[i, j], b[i, j] = x[i, j], y[i, j], z[i, j]
                h[i, j] = h[i, j] - (2*np.pi/3)
    #print(r[0], g[0], b[0])
    rgb = cv2.merge((r*255, g*255, b*255))
    return rgb

# %%
rgb = HSI_TO_RGB(hsi)

# %%
#hsi = RGB_TO_HSI(plt.imread("img1.jpg"))
cv2.imshow('HSI Image', rgb)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def rgb_to_hsi(img):
    
    zmax = 255 # max value
    # values in [0,1]
    R = np.divide(img[:,:,0],zmax,dtype=np.float)
    G = np.divide(img[:,:,1],zmax,dtype=np.float)
    B = np.divide(img[:,:,2],zmax,dtype=np.float)

    # Hue, when R=G=B -> H=90
    a = (0.5)*np.add(np.subtract(R,G), np.subtract(R,B)) # (1/2)*[(R-G)+(R-B)]
    b = np.sqrt(np.add(np.power(np.subtract(R,G), 2) , np.multiply(np.subtract(R,B),np.subtract(G,B))))
    tetha = np.arccos( np.divide(a, b, out=np.zeros_like(a), where=b!=0) ) # when b = 0, division returns 0, so then tetha = 90
    H = (180/math.pi)*tetha # convert rad to degree
    H[B>G]=360-H[B>G]

    # saturation = 1 - 3*[min(R,G,B)]/(R+G+B), when R=G=B -> S=0
    a = 3*np.minimum(np.minimum(R,G),B) # 3*min(R,G,B)
    b = np.add(np.add(R,G),B) # (R+G+B)
    S = np.subtract(1, np.divide(a,b,out=np.ones_like(a),where=b!=0))

    # intensity = (1/3)*[R+G+B]
    I = (1/3)*np.add(np.add(R,G),B)

    return np.dstack((H, zmax*S, np.round(zmax*I))), I # values between [0,360], [0,255] e [0,255]

# %%
def f1(I,S): # I(1-S)
    return np.multiply(I, np.subtract(1,S))
    
def f2(I,S,H): # I[1+(ScosH/cos(60-H))]
    r = math.pi/180
    a = np.multiply(S, np.cos(r*H)) # ScosH
    b = np.cos(r*np.subtract(60,H)) # cos(60-H)
    return np.multiply(I, np.add(1, np.divide(a,b)) )

def f3(I,C1,C2): # 3I-(C1+C2)
    return np.subtract(3*I, np.add(C1,C2))

def hsi_to_rgb(img):
    zmax = 255 # max value
    # values between[0,360], [0,1] and [0,1]
    H = img[:,:,0]
    S = np.divide(img[:,:,1],zmax,dtype=np.float)
    I = np.divide(img[:,:,2],zmax,dtype=np.float)

    R,G,B = np.ones(H.shape),np.ones(H.shape),np.ones(H.shape) # values will be between [0,1]
    # for 0 <= H < 120
    B[(0<=H)&(H<120)] = f1(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)])
    R[(0<=H)&(H<120)] = f2(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)], H[(0<=H)&(H<120)])
    G[(0<=H)&(H<120)] = f3(I[(0<=H)&(H<120)], R[(0<=H)&(H<120)], B[(0<=H)&(H<120)])

    # for 120 <= H < 240
    H = np.subtract(H,120)
    R[(0<=H)&(H<120)] = f1(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)])
    G[(0<=H)&(H<120)] = f2(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)], H[(0<=H)&(H<120)])
    B[(0<=H)&(H<120)] = f3(I[(0<=H)&(H<120)], R[(0<=H)&(H<120)], G[(0<=H)&(H<120)])

    # for 240 <= H < 360
    H = np.subtract(H,120)
    G[(0<=H)&(H<120)] = f1(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)])
    B[(0<=H)&(H<120)] = f2(I[(0<=H)&(H<120)], S[(0<=H)&(H<120)], H[(0<=H)&(H<120)])
    R[(0<=H)&(H<120)] = f3(I[(0<=H)&(H<120)], G[(0<=H)&(H<120)], B[(0<=H)&(H<120)])

    #return np.dstack( (np.clip(zmax*R, 0, 255) , np.clip(zmax*G, 0, 255) , np.clip(zmax*B, 0, 255)) ) # values between [0,255]
    return np.dstack( ((zmax*R) , (zmax*G) ,(zmax*B)) )

# %%
hsi, I = rgb_to_hsi(plt.imread("img2.jpg"))

hsi1 = (hsi - hsi.min()) / (hsi.max() - hsi.min())
plt.imshow(hsi1)

# %%
rgb = hsi_to_rgb(hsi)

rgb1 = (rgb - rgb.min()) / (rgb.max() - rgb.min())
plt.imshow(rgb1)

# %%
plt.imshow(I)
I
# Out:
# array([[0.57385621, 0.57385621, 0.56993464, ..., 0.7372549 , 0.7372549 ,
#         0.74117647],
#        [0.57385621, 0.57385621, 0.57385621, ..., 0.73986928, 0.74379085,
#         0.74379085],
#        [0.57385621, 0.57777778, 0.57647059, ..., 0.74509804, 0.74509804,
#         0.74509804],
#        ...,
#        [0.25751634, 0.2627451 , 0.18300654, ..., 0.48627451, 0.24313725,
#         0.18562092],
#        [0.26797386, 0.27320261, 0.25098039, ..., 0.47843137, 0.23921569,
#         0.19346405],
#        [0.26797386, 0.25359477, 0.2379085 , ..., 0.48235294, 0.23529412,
#         0.19738562]])

# %%
(I*255).astype("uint8")
# Out:
# array([[146, 146, 145, ..., 188, 188, 189],
#        [146, 146, 146, ..., 188, 189, 189],
#        [146, 147, 147, ..., 190, 190, 190],
#        ...,
#        [ 65,  66,  46, ..., 124,  62,  47],
#        [ 68,  69,  64, ..., 121,  60,  49],
#        [ 68,  64,  60, ..., 122,  59,  50]], dtype=uint8)

# %%
def int2bin_1ch(i):
    return ('{0:08b}'.format(i))


def mergeT2Im(I, hide_text):
    
    Ibin = np.empty(I.shape)
    
    for i in range(I.shape[0]):
        for j in range(I.shape[1]):
            if(i<2 and j<2):
                string = int2bin_1ch(I[i, j])
                print(string)
                string[-1] = '1'
                print(string)
            Ibin[i,j] = int2bin_1ch(I[i, j])
    
    return Ibin

# %%
Ibin = mergeT2Im((I*255).astype("uint8"))
# Out:
# 10010010
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-95d293ce9a6c> in <module>()
# ----> 1 Ibin = mergeT2Im((I*255).astype("uint8"))
#
# <ipython-input-171-65c49b6c8df5> in mergeT2Im(I)
#      12                 string = int2bin_1ch(I[i, j])
#      13                 print(string)
# ---> 14                 string[-1] = '1'
#      15                 print(string)
#      16             Ibin[i,j] = int2bin_1ch(I[i, j])
#
# TypeError: 'str' object does not support item assignment

# %%
hide_text = "National Institute of Technology, Karnataka"

# %%
def str2bin(string):
    bin_str = ""
    
    for i in string:    
        bin_str = bin_str + ("{0:08b}".format(ord(i)))
    
    return bin_str

# %%
bin_str = str2bin(hide_text)

# %%
def text_hide(I, string):
    
    bin_str = str2bin(string)
    Ibin =  int2binI((I*255).astype("uint8"))

# %%
for i in range(len(bin_str)):
    
    Ibin2 = Ibin.reshape(-1)
    
    Ibin[]

# %%
Ibin2 = Ibin.reshape(-1)
type(Ibin2[0])
# Out:
# numpy.str_

# %%
Ibin
# Out:
# array([[10010010., 10010010., 10010001., ..., 10111100., 10111100.,
#         10111101.],
#        [10010010., 10010010., 10010010., ..., 10111100., 10111101.,
#         10111101.],
#        [10010010., 10010011., 10010011., ..., 10111110., 10111110.,
#         10111110.],
#        ...,
#        [ 1000001.,  1000010.,   101110., ...,  1111100.,   111110.,
#           101111.],
#        [ 1000100.,  1000101.,  1000000., ...,  1111001.,   111100.,
#           110001.],
#        [ 1000100.,  1000000.,   111100., ...,  1111010.,   111011.,
#           110010.]])

# %%
#hsi, I = rgb_to_hsi(plt.imread("img2.jpg"))

#cover_image 512*512*3
# total = 512*512
# total/x*y*8 = 512*64 = 256*128 grayscale
#img2 = read 2nd image

#img2 -> x*y*3 -> bin 1D array -> 2D to 1D -> bin -> x*y*8 bits string

#convI(I, img2_binstring)
    # 2 for pixels 
    # bin(I[i, j]) , 4 bits change

# %%
I1 = (I*255).astype("uint8")

# %%
def chnbits(i1, str1):
    i1bin = ("{0:08b}".format(i1))
    #print(i1bin)
    result = i1bin[:4] + str1
    #print(result)
    return result

def bin2int(bin1):
    
    return(int(bin1, 2))

# %%
bin2int(chnbits(220, '0000'))
# Out:
# 208

# %%
img_bird = plt.imread("bird_small.png")
img_bird = (img_bird*255).astype('int')
plt.imshow(img_bird)

# %%
#img_bird_bin = np.empty(img_bird.shape[0], img_bird)
str1 = ""
for i in range(img_bird.shape[0]):
    for j in range(img_bird.shape[1]):
        
        rgb_bin_tuple = int_to_bin(tuple(img_bird[i][j]))
        
        str1  = str1 + rgb_bin_tuple[0][:4] + rgb_bin_tuple[1][:4] + rgb_bin_tuple[2][:4]

        #print(tuple(img_bird[0][0]), rgb_bin_tuple, str1)
        
print(len(str1))
# Out:
# 196608

# %%
I1bin = np.empty(I1.shape)
str_idx = 0
for i in range((I1.shape[0])):
    for j in range((I1.shape[1])):
        if(str_idx < len(str1)):
            I1bin[i, j] = bin2int(chnbits(I1[i,j], str1[str_idx:str_idx+4]))
            str_idx = str_idx + 4
        else:
            I1bin[i, j] = I1[i, j]

# %%
plt.figure(figsize = (12, 9))
plt.subplot(121)
plt.imshow(I1bin)
plt.title("Bin changed")

plt.subplot(122)
plt.imshow(I1)
plt.title("original")
plt.show()

# %%
I1bin_norm = (I1bin - I1bin.min())/(I1bin.max() - I1bin.min())

# %%
h, s = hsi[:, : ,0], hsi[:, : ,1]
hsi_ch = np.dstack((h, s, I1bin_norm))

# %%
#hsi_norm = (hsi_ch - hsi_ch.min())/(hsi_ch.max() - hsi_ch.min())
plt.figure(figsize = (12, 9))
plt.subplot(121)
plt.imshow(hsi_to_rgb(hsi_ch))
plt.title("Bin changed")

plt.subplot(122)
plt.imshow(plt.imread("img2.jpg"))
plt.title("original")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# image, 
# PSNR, MSE, 
# Compare 4bit inRGB and 4bit chn HSI
# I = img.shape 1000*700*4 ==> 128*128*12

# %%
import cv2
img2 = cv2.imread("data/lena.tif")

cv2.imshow("R", img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
lena = cv2.imread("data/lena.tif")
lena2 = cv2.resize(lena, (1024, 1024),  
               interpolation = cv2.INTER_NEAREST)
